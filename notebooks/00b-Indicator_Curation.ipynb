# %% [markdown]
# # 1 - Imports

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parents[0]))

# %%
import pandas as pd
import numpy as np

# %%
from src.utils import templates, config, io
# Out:
# /Users/hippolytegrandet/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/pypdf/_crypt_providers/_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %% [markdown]
# # 1 - Retrieving Features Descriptions

# %%
from src.extraction import dbnomics_client

# %%
import pandas as pd
import dbnomics

def format_api_link(provider: str, dataset: str, indicator: str) -> str:
    """get api link for the indicator.

    Args:
        provider (string): name of the provider of the indicator.
        dataset (string): name of the dataset of the indicator.
        indicator (string): name of the indicator.

    Returns:
        string: formated api link, to get indicator df from dbnomics api.
    """

    link_p1 = 'https://api.db.nomics.world/v22/series/'
    link_p3 = '%22%5D%7D&observations=1'

    if provider == 'WB':
        link_p2 = '?dimensions=%7B%22indicator%22%3A%5B%22'
    elif provider == 'IMF':
        link_p2 = '?dimensions=%7B%22INDICATOR%22%3A%5B%22'
        # link_p3 = link_p3 + '&q=imf'
    else:
        return ''

    api_link = link_p1 + provider + '/' + dataset + link_p2 + indicator + link_p3
    return api_link

def fetch_indicator(provider: str, dataset: str, indicator: str) -> pd.DataFrame:
    """get unformated indicator df from dbnomics api.
    Args:
        provider (string): name of the provider of the indicator.
        dataset (string): name of the dataset of the indicator.
        indicator (string): name of the indicator.
    Returns:
        DataFrame: indicator df from dbnomics api.
    """

    api_link = format_api_link(provider, dataset, indicator)
    try:
        df_indicator = dbnomics.fetch_series_by_api_link(
            api_link,
            max_nb_series=600
        )
        print(df_indicator)
    except Exception:
        print('Error Fetching Series for indicator', indicator)
        df_indicator = pd.DataFrame()

    return df_indicator

# %%
df = dbnomics.fetch_series(
    api_base_url='https://api.db.nomics.world/v22/',
    provider_code='AMECO',
    dataset_code='ZUTN',
)
df
# Out:
#    @frequency provider_code dataset_code  \
# 0      annual         AMECO         ZUTN
# 1      annual         AMECO         ZUTN
# 2      annual         AMECO         ZUTN
# 3      annual         AMECO         ZUTN
# 4      annual         AMECO         ZUTN
# ..        ...           ...          ...
# 63     annual         AMECO         ZUTN
# 64     annual         AMECO         ZUTN
# 65     annual         AMECO         ZUTN
# 66     annual         AMECO         ZUTN
# 67     annual         AMECO         ZUTN
#
#                                          dataset_name       series_code  \
# 0   Unemployment rate: total :- Member States: def...  ALB.1.0.0.0.ZUTN
# 1   Unemployment rate: total :- Member States: def...  ALB.1.0.0.0.ZUTN
# 2   Unemployment rate: total :- Member States: def...  ALB.1.0.0.0.ZUTN
# 3   Unemployment rate: total :- Member States: def...  ALB.1.0.0.0.ZUTN
# 4   Unemployment rate: total :- Member States: def...  ALB.1.0.0.0.ZUTN
# ..                                                ...               ...
# 63  Unemployment rate: total :- Member States: def...  USA.1.0.0.0.ZUTN
# 64  Unemployment rate: total :- Member States: def...  USA.1.0.0.0.ZUTN
# 65  Unemployment rate: total :- Member States: def...  USA.1.0.0.0.ZUTN
# 66  Unemployment rate: total :- Member States: def...  USA.1.0.0.0.ZUTN
# 67  Unemployment rate: total :- Member States: def...  USA.1.0.0.0.ZUTN
#
#                                           series_name original_period  \
# 0   Annually – (Percentage of active population) –...            1960
# 1   Annually – (Percentage of active population) –...            1961
# 2   Annually – (Percentage of active population) –...            1962
# 3   Annually – (Percentage of active population) –...            1963
# 4   Annually – (Percentage of active population) –...            1964
# ..                                                ...             ...
# 63  Annually – (Percentage of active population) –...            2023
# 64  Annually – (Percentage of active population) –...            2024
# 65  Annually – (Percentage of active population) –...            2025
# 66  Annually – (Percentage of active population) –...            2026
# 67  Annually – (Percentage of active population) –...            2027
#
#        period original_value  value freq                             unit  \
# 0  1960-01-01             NA    NaN    a  percentage-of-active-population
# 1  1961-01-01             NA    NaN    a  percentage-of-active-population
# 2  1962-01-01             NA    NaN    a  percentage-of-active-population
# 3  1963-01-01             NA    NaN    a  percentage-of-active-population
# 4  1964-01-01             NA    NaN    a  percentage-of-active-population
# ..        ...            ...    ...  ...                              ...
# 63 2023-01-01            3.6    3.6    a  percentage-of-active-population
# 64 2024-01-01            4.0    4.0    a  percentage-of-active-population
# 65 2025-01-01            4.2    4.2    a  percentage-of-active-population
# 66 2026-01-01            4.4    4.4    a  percentage-of-active-population
# 67 2027-01-01            4.3    4.3    a  percentage-of-active-population
#
#     geo Frequency                               Unit        Country
# 0   alb  Annually  (Percentage of active population)        Albania
# 1   alb  Annually  (Percentage of active population)        Albania
# 2   alb  Annually  (Percentage of active population)        Albania
# 3   alb  Annually  (Percentage of active population)        Albania
# 4   alb  Annually  (Percentage of active population)        Albania
# ..  ...       ...                                ...            ...
# 63  usa  Annually  (Percentage of active population)  United States
# 64  usa  Annually  (Percentage of active population)  United States
# 65  usa  Annually  (Percentage of active population)  United States
# 66  usa  Annually  (Percentage of active population)  United States
# 67  usa  Annually  (Percentage of active population)  United States
#
# [3400 rows x 16 columns]

# %%
df['series_name'].value_counts()
# Out:
# series_name
# Annually – (Percentage of active population) – Albania                              68
# Annually – (Percentage of active population) – Australia                            68
# Annually – (Percentage of active population) – Austria                              68
# Annually – (Percentage of active population) – Belgium                              68
# Annually – (Percentage of active population) – Bulgaria                             68
# Annually – (Percentage of active population) – Canada                               68
# Annually – (Percentage of active population) – Switzerland                          68
# Annually – (Percentage of active population) – Cyprus                               68
# Annually – (Percentage of active population) – Czech Republic                       68
# Annually – (Percentage of active population) – EA12 (including D_W West-Germany)    68
# Annually – (Percentage of active population) – Germany                              68
# Annually – (Percentage of active population) – Denmark                              68
# Annually – (Percentage of active population) – EU15 (including D_W West-Germany)    68
# Annually – (Percentage of active population) – West Germany                         68
# Annually – (Percentage of active population) – Euro area (12 countries)             68
# Annually – (Percentage of active population) – Euro area (19 countries)             68
# Annually – (Percentage of active population) – Euro area (20 countries)             68
# Annually – (Percentage of active population) – Spain                                68
# Annually – (Percentage of active population) – Estonia                              68
# Annually – (Percentage of active population) – European Union (15 countries)        68
# Annually – (Percentage of active population) – European Union                       68
# Annually – (Percentage of active population) – Finland                              68
# Annually – (Percentage of active population) – France                               68
# Annually – (Percentage of active population) – United Kingdom                       68
# Annually – (Percentage of active population) – Greece                               68
# Annually – (Percentage of active population) – Croatia                              68
# Annually – (Percentage of active population) – Hungary                              68
# Annually – (Percentage of active population) – Ireland                              68
# Annually – (Percentage of active population) – Iceland                              68
# Annually – (Percentage of active population) – Italy                                68
# Annually – (Percentage of active population) – Japan                                68
# Annually – (Percentage of active population) – Korea                                68
# Annually – (Percentage of active population) – Lithuania                            68
# Annually – (Percentage of active population) – Luxembourg                           68
# Annually – (Percentage of active population) – Latvia                               68
# Annually – (Percentage of active population) – North Macedonia                      68
# Annually – (Percentage of active population) – Malta                                68
# Annually – (Percentage of active population) – Montenegro                           68
# Annually – (Percentage of active population) – Netherlands                          68
# Annually – (Percentage of active population) – Norway                               68
# Annually – (Percentage of active population) – New Zealand                          68
# Annually – (Percentage of active population) – Poland                               68
# Annually – (Percentage of active population) – Portugal                             68
# Annually – (Percentage of active population) – Romania                              68
# Annually – (Percentage of active population) – Serbia                               68
# Annually – (Percentage of active population) – Slovakia                             68
# Annually – (Percentage of active population) – Slovenia                             68
# Annually – (Percentage of active population) – Sweden                               68
# Annually – (Percentage of active population) – Türkiye                              68
# Annually – (Percentage of active population) – United States                        68
# Name: count, dtype: int64

# %%
df = dbnomics.fetch_series(['WB/WDI/NY.ADJ.DPEM.GN.ZS'])
df
# Out:
# Could not load series: {'dataset_code': 'WDI', 'message': 'Could not load series', 'provider_code': 'WB', 'series_code': 'NY.ADJ.DPEM.GN.ZS'}
# Empty DataFrame
# Columns: []
# Index: []

# %%
df3 = dbnomics.fetch_series("WB", "DB", dimensions={
    "country": ["FR", "IT", "ES"],
    "indicator": ["IC.REG.COST.PC.FE.ZS.DRFN"],
})
df3
# Out:
# Finished call to 'dbnomics._fetch_response' after 0.410(s), this was the 1st time calling it.
# Finished call to 'dbnomics._fetch_response' after 1.337(s), this was the 2nd time calling it.
# Finished call to 'dbnomics._fetch_response' after 3.258(s), this was the 3rd time calling it.
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/dbnomics/__init__.py:577, in _fetch_response(url, timeout)
#     575     raise TryAgain
# --> 577 response.raise_for_status()
#     579 return response
#
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '404 NOT FOUND' for url 'https://api.db.nomics.world/v22/series/WB/DB?observations=1&dimensions={%22country%22:%20[%22FR%22,%20%22IT%22,%20%22ES%22],%20%22indicator%22:%20[%22IC.REG.COST.PC.FE.ZS.DRFN%22]}&offset=0'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/dbnomics/__init__.py:345, in fetch_series_page(series_endpoint_url, offset, timeout)
#     344 try:
# --> 345     response = _fetch_response(series_page_url, timeout=timeout)
#     346 except RetryError as exc:
#
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/tenacity/__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/tenacity/__init__.py:421, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     420     raise retry_exc.reraise()
# --> 421 raise retry_exc from fut.exception()
#
# RetryError: RetryError[<Future at 0x1314701c0 state=finished raised HTTPStatusError>]
#
# The above exception was the direct cause of the following exception:
#
# FetchError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df3 = dbnomics.fetch_series("WB", "DB", dimensions={
#       2     "country": ["FR", "IT", "ES"],
#       3     "indicator": ["IC.REG.COST.PC.FE.ZS.DRFN"],
#       4 })
#       5 df3
#
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/dbnomics/__init__.py:162, in fetch_series(provider_code, dataset_code, series_code, dimensions, series_ids, max_nb_series, api_base_url, editor_api_base_url, filters, timeout)
#     158         raise ValueError(msg)
#     159     api_link = series_base_url + "/{}/{}?observations=1&dimensions={}".format(
#     160         provider_code, dataset_code, json.dumps(dimensions)
#     161     )
# --> 162     return fetch_series_by_api_link(
#     163         api_link,
#     164         filters=filters,
#     165         max_nb_series=max_nb_series,
#     166         editor_api_base_url=editor_api_base_url,
#     167         timeout=timeout,
#     168     )
#     170 if series_code is not None:
#     171     if not provider_code or not dataset_code:
#
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/dbnomics/__init__.py:235, in fetch_series_by_api_link(api_link, max_nb_series, editor_api_base_url, filters, timeout)
#     225 # series_dims_by_dataset_code example:
#     226 #    {
#     227 #        'WB/DB': {
#    (...)
#     232 #        ...
#     233 #    }
#     234 series_list = []
# --> 235 for series_infos in iter_series_infos(api_link, max_nb_series=max_nb_series, timeout=timeout):
#     236     complete_dataset_code = (
#     237         series_infos["series"]["provider_code"] + "/" + series_infos["series"]["dataset_code"]
#     238     )  # ex 'AMECO/ZUTN'
#     239     if datasets_dimensions is None:
#     240         # Let see if there's only one dataset returned by API, or many datasets
#
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/dbnomics/__init__.py:442, in iter_series_infos(api_link, max_nb_series, timeout)
#     439 total_nb_series = 0
#     441 while True:
# --> 442     response_json = fetch_series_page(api_link, offset=total_nb_series, timeout=timeout)
#     444     errors = response_json.get("errors")
#     445     if errors:
#
# File ~/Desktop/Dev/country_risk_rating/.venv/lib/python3.9/site-packages/dbnomics/__init__.py:347, in fetch_series_page(series_endpoint_url, offset, timeout)
#     345     response = _fetch_response(series_page_url, timeout=timeout)
#     346 except RetryError as exc:
# --> 347     raise FetchError(url=series_page_url) from exc
#     349 response_json = response.json()
#     351 series_page = response_json.get("series")
#
# FetchError: Could not fetch data from URL 'https://api.db.nomics.world/v22/series/WB/DB?observations=1&dimensions={"country": ["FR", "IT", "ES"], "indicator": ["IC.REG.COST.PC.FE.ZS.DRFN"]}&offset=0'

# %%
df2 = dbnomics.fetch_series([
    'AMECO/ZUTN/EA19.1.0.0.0.ZUTN',
    'AMECO/ZUTN/DNK.1.0.0.0.ZUTN',
])
df2
# Out:
#    @frequency provider_code dataset_code  \
# 0      annual         AMECO         ZUTN
# 1      annual         AMECO         ZUTN
# 2      annual         AMECO         ZUTN
# 3      annual         AMECO         ZUTN
# 4      annual         AMECO         ZUTN
# ..        ...           ...          ...
# 63     annual         AMECO         ZUTN
# 64     annual         AMECO         ZUTN
# 65     annual         AMECO         ZUTN
# 66     annual         AMECO         ZUTN
# 67     annual         AMECO         ZUTN
#
#                                          dataset_name        series_code  \
# 0   Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 1   Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 2   Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 3   Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# 4   Unemployment rate: total :- Member States: def...  EA19.1.0.0.0.ZUTN
# ..                                                ...                ...
# 63  Unemployment rate: total :- Member States: def...   DNK.1.0.0.0.ZUTN
# 64  Unemployment rate: total :- Member States: def...   DNK.1.0.0.0.ZUTN
# 65  Unemployment rate: total :- Member States: def...   DNK.1.0.0.0.ZUTN
# 66  Unemployment rate: total :- Member States: def...   DNK.1.0.0.0.ZUTN
# 67  Unemployment rate: total :- Member States: def...   DNK.1.0.0.0.ZUTN
#
#                                           series_name original_period  \
# 0   Annually – (Percentage of active population) –...            1960
# 1   Annually – (Percentage of active population) –...            1961
# 2   Annually – (Percentage of active population) –...            1962
# 3   Annually – (Percentage of active population) –...            1963
# 4   Annually – (Percentage of active population) –...            1964
# ..                                                ...             ...
# 63  Annually – (Percentage of active population) –...            2023
# 64  Annually – (Percentage of active population) –...            2024
# 65  Annually – (Percentage of active population) –...            2025
# 66  Annually – (Percentage of active population) –...            2026
# 67  Annually – (Percentage of active population) –...            2027
#
#        period original_value  value freq                             unit  \
# 0  1960-01-01             NA    NaN    a  percentage-of-active-population
# 1  1961-01-01             NA    NaN    a  percentage-of-active-population
# 2  1962-01-01             NA    NaN    a  percentage-of-active-population
# 3  1963-01-01             NA    NaN    a  percentage-of-active-population
# 4  1964-01-01             NA    NaN    a  percentage-of-active-population
# ..        ...            ...    ...  ...                              ...
# 63 2023-01-01            5.1    5.1    a  percentage-of-active-population
# 64 2024-01-01            6.2    6.2    a  percentage-of-active-population
# 65 2025-01-01            6.1    6.1    a  percentage-of-active-population
# 66 2026-01-01            6.1    6.1    a  percentage-of-active-population
# 67 2027-01-01            6.0    6.0    a  percentage-of-active-population
#
#      geo Frequency                               Unit  \
# 0   ea19  Annually  (Percentage of active population)
# 1   ea19  Annually  (Percentage of active population)
# 2   ea19  Annually  (Percentage of active population)
# 3   ea19  Annually  (Percentage of active population)
# 4   ea19  Annually  (Percentage of active population)
# ..   ...       ...                                ...
# 63   dnk  Annually  (Percentage of active population)
# 64   dnk  Annually  (Percentage of active population)
# 65   dnk  Annually  (Percentage of active population)
# 66   dnk  Annually  (Percentage of active population)
# 67   dnk  Annually  (Percentage of active population)
#
#                      Country
# 0   Euro area (19 countries)
# 1   Euro area (19 countries)
# 2   Euro area (19 countries)
# 3   Euro area (19 countries)
# 4   Euro area (19 countries)
# ..                       ...
# 63                   Denmark
# 64                   Denmark
# 65                   Denmark
# 66                   Denmark
# 67                   Denmark
#
# [136 rows x 16 columns]

# %%
df_indicator = fetch_indicator('IMF', 'WDI', 'NY.ADJ.DPEM.GN.ZS')
df_indicator
# Out:
# Finished call to 'dbnomics._fetch_response' after 0.179(s), this was the 1st time calling it.
# Finished call to 'dbnomics._fetch_response' after 0.559(s), this was the 2nd time calling it.
# Finished call to 'dbnomics._fetch_response' after 1.513(s), this was the 3rd time calling it.
# Error Fetching Series for indicator NY.ADJ.DPEM.GN.ZS
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # 2 - Querying LLM

# %%
prompt = USER_TEMPLATE.format(
    name=row["indicator_name"],
    description=row["description"]
)

response = llm_client.chat(
    system=SYSTEM_PROMPT,
    user=prompt,
    temperature=0
)

results.append({
    "indicator_id": row["indicator_id"],
    "name": row["indicator_name"],
    "relevance_score": response["relevance_score"],
    "justification": response["justification"]
})
