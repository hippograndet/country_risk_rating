# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parents[0]))

# %%
import os

# %%
import pandas as pd
from pickle import dump, load

# %%
from datetime import datetime

# %%
from src.utils import config

# %%
from src.extraction import build_oecd_dataset

# %%
m = build_oecd_dataset.get_clean_oecd_rating_df(oecd_fname='02-02-2024')
m
# Out:
# On page: 84
#                   1999-01-01 1999-04-01 1999-07-01 1999-10-01 2000-01-01  \
# ISO3_COUNTRY_CODE
# AFG                        7          7          7          7          7
# ALB                        7          7          7          7          7
# DZA                        6          6          6          6          6
# AND                        -          -          -          -          -
# AGO                        7          7          7          7          7
# ...                      ...        ...        ...        ...        ...
# VNM                        6          6          6          6          6
# PSE                        -          -          -          -          -
# YEM                        7          7          7          7          7
# ZMB                        7          7          7          7          7
# ZWE                        5          6          6          6          6
#
#                   2000-04-01 2000-07-01 2000-10-01 2001-01-01 2001-04-01  ...  \
# ISO3_COUNTRY_CODE                                                         ...
# AFG                        -          -          -          -          -  ...
# ALB                        7          7          7          7          7  ...
# DZA                        6          6          5          5          5  ...
# AND                        -          -          -          -          -  ...
# AGO                        7          7          7          7          7  ...
# ...                      ...        ...        ...        ...        ...  ...
# VNM                        6          6          6          6          6  ...
# PSE                        -          -          -          -          -  ...
# YEM                        7          7          7          7          7  ...
# ZMB                        7          7          7          7          7  ...
# ZWE                        7          7          7          7          7  ...
#
#                   2021-07-01 2021-10-01 2022-01-01 2022-04-01 2022-07-01  \
# ISO3_COUNTRY_CODE
# AFG                        7          7          7          7          7
# ALB                        5          5          5          5          5
# DZA                        5          5          5          5          5
# AND                        -          -          -          -          -
# AGO                        6          6          6          6          6
# ...                      ...        ...        ...        ...        ...
# VNM                        4          4          4          4          4
# PSE                        7          7          7          7          7
# YEM                        7          7          7          7          7
# ZMB                        7          7          7          7          7
# ZWE                        7          7          7          7          7
#
#                   2022-10-01 2023-01-01 2023-04-01 2023-07-01 2023-10-01
# ISO3_COUNTRY_CODE
# AFG                        7          7          7          7          7
# ALB                        5          5          5          5          5
# DZA                        5          5          5          5          5
# AND                        -          -          -          -          -
# AGO                        6          6          6          6          6
# ...                      ...        ...        ...        ...        ...
# VNM                        4          4          4          4          4
# PSE                        7          7          7          7          7
# YEM                        7          7          7          7          7
# ZMB                        7          7          7          7          7
# ZWE                        7          7          7          7          7
#
# [201 rows x 100 columns]

# %%
oecd_rating_matrix.to_csv(io. + 'intermed_data/oecd/oecd_rating_matrix_yearly.csv')
# Out:
# Index(['1999-01-01', '1999-04-01', '1999-07-01', '1999-10-01', '2000-01-01',
#        '2000-04-01', '2000-07-01', '2000-10-01', '2001-01-01', '2001-04-01',
#        ...
#        '2024-07-01', '2024-10-01', '2025-01-01', '2025-04-01', '2025-07-01',
#        '2025-10-01', '2026-01-01', '2026-04-01', '2026-07-01', '2026-10-01'],
#       dtype='object', length=112)
