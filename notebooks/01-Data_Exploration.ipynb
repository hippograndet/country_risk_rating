# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from pickle import dump, load

# %%
import sys
sys.path.append('../')

# %%
from src import addresses

# %%
addresses
# Out:
# <module 'src.addresses' from '/Users/hippolytegrandet/Desktop/Dev/country_risk_rating/notebooks/../src/addresses.py'>

# %%
addresses.company_BE_address
# Out:
# 's3://lab-data-project/report/BackEnd/BE_DSP_v1/company/'
